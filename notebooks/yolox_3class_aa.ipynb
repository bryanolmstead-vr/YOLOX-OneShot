# %% [markdown]
# Clone the YOLOX repo fork and my YOLO-Oneshot repo

# %%
# !git clone https://github.com/bryanolmstead-vr/YOLOX-fork.git
# !git clone https://github.com/bryanolmstead-vr/YOLOX-OneShot.git
# Out:
# Cloning into 'YOLOX-fork'...
# remote: Enumerating objects: 1958, done.
# remote: Counting objects: 100% (1958/1958), done.
# remote: Compressing objects: 100% (723/723), done.
# remote: Total 1958 (delta 1174), reused 1952 (delta 1168), pack-reused 0 (from 0)
# Receiving objects: 100% (1958/1958), 7.62 MiB | 15.97 MiB/s, done.
# Resolving deltas: 100% (1174/1174), done.
# Cloning into 'YOLOX-OneShot'...
# remote: Enumerating objects: 1210, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 1210 (delta 1), reused 2 (delta 1), pack-reused 1203 (from 1)
# Receiving objects: 100% (1210/1210), 143.53 MiB | 23.25 MiB/s, done.
# Resolving deltas: 100% (62/62), done.
# Updating files: 100% (1447/1447), done.

# %% [markdown]
# install YOLOX dependencies

# %%
# %cd /content/YOLOX-fork
# Install core dependencies first
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install opencv-python loguru tqdm pycocotools tabulate psutil tensorboard thop ninja onnx onnx-simplifier==0.5.0

# Install the rest
# !pip install -v -e . --no-deps
# Out:
# /content/YOLOX-fork
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.10.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.25.0+cu128)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (2.10.0+cu128)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.13.0.92)
# Collecting loguru
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.12/dist-packages (2.0.11)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (0.9.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (5.9.5)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Collecting thop
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Collecting ninja
#   Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Collecting onnx
#   Downloading onnx-1.20.1-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Collecting onnx-simplifier==0.5.0
#   Downloading onnx_simplifier-0.5.0.tar.gz (728 bytes)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting onnxsim (from onnx-simplifier==0.5.0)
#   Downloading onnxsim-0.6.2-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (1.78.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (3.10.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorboard) (26.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (5.29.6)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (3.1.6)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from thop) (2.10.0+cu128)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from onnx) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx) (0.5.4)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard) (3.0.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from onnxsim->onnx-simplifier==0.5.0) (13.9.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.24.3)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->thop) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->thop) (1.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->thop) (1.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->onnxsim->onnx-simplifier==0.5.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->onnxsim->onnx-simplifier==0.5.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->onnxsim->onnx-simplifier==0.5.0) (0.1.2)
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 7.5 MB/s eta 0:00:00
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 14.0 MB/s eta 0:00:00
# Downloading onnx-1.20.1-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.5/17.5 MB 102.3 MB/s eta 0:00:00
# Downloading onnxsim-0.6.2-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 79.3 MB/s eta 0:00:00
# Building wheels for collected packages: onnx-simplifier
#   Building wheel for onnx-simplifier (pyproject.toml) ... done
#   Created wheel for onnx-simplifier: filename=onnx_simplifier-0.5.0-py3-none-any.whl size=1022 sha256=d13125c9e19db5ab35283de208594d5e977c1cb8431f3733f89c6c8a472b91bc
#   Stored in directory: /root/.cache/pip/wheels/f0/61/52/656a88deb2107e0239543f2bdfab560c47fcf74c3d29765c5e
# Successfully built onnx-simplifier
# Installing collected packages: ninja, loguru, onnx, onnxsim, thop, onnx-simplifier
# Successfully installed loguru-0.7.3 ninja-1.13.0 onnx-1.20.1 onnx-simplifier-0.5.0 onnxsim-0.6.2 thop-0.1.1.post2209072238
# Using pip 24.1.2 from /usr/local/lib/python3.12/dist-packages/pip (python 3.12)
# Obtaining file:///content/YOLOX-fork
#   Running command python setup.py egg_info
#   /usr/local/lib/python3.12/dist-packages/setuptools/__init__.py:94: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#   !!
#
#           ********************************************************************************
#           Requirements should be satisfied by a PEP 517 installer.
#           If you are using pip, you can try `pip install --use-pep517`.
#           ********************************************************************************
#
#   !!
#     dist.fetch_build_eggs(dist.setup_requires)
#   running egg_info
#   creating /tmp/pip-pip-egg-info-i59hor_g/yolox.egg-info
#   writing /tmp/pip-pip-egg-info-i59hor_g/yolox.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-i59hor_g/yolox.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-pip-egg-info-i59hor_g/yolox.egg-info/requires.txt
#   writing top-level names to /tmp/pip-pip-egg-info-i59hor_g/yolox.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-i59hor_g/yolox.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-pip-egg-info-i59hor_g/yolox.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching '*.cu' under directory 'yolox'
#   warning: no files found matching '*.cuh' under directory 'yolox'
#   warning: no files found matching '*.cc' under directory 'yolox'
#   adding license file 'LICENSE'
#   writing manifest file '/tmp/pip-pip-egg-info-i59hor_g/yolox.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# Installing collected packages: yolox
#   Running setup.py develop for yolox
#     Running command python setup.py develop
#     /usr/local/lib/python3.12/dist-packages/setuptools/__init__.py:94: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#     !!
#
#             ********************************************************************************
#             Requirements should be satisfied by a PEP 517 installer.
#             If you are using pip, you can try `pip install --use-pep517`.
#             ********************************************************************************
#
#     !!
#       dist.fetch_build_eggs(dist.setup_requires)
#     running develop
#     /usr/local/lib/python3.12/dist-packages/setuptools/command/develop.py:41: EasyInstallDeprecationWarning: easy_install command is deprecated.
#     !!
#
#             ********************************************************************************
#             Please avoid running ``setup.py`` and ``easy_install``.
#             Instead, use pypa/build, pypa/installer or other
#             standards-based tools.
#
#             See https://github.com/pypa/setuptools/issues/917 for details.
#             ********************************************************************************
#
#     !!
#       easy_install.initialize_options(self)
#     /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
#     !!
#
#             ********************************************************************************
#             Please avoid running ``setup.py`` directly.
#             Instead, use pypa/build, pypa/installer or other
#             standards-based tools.
#
#             See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#             ********************************************************************************
#
#     !!
#       self.initialize_options()
#     running egg_info
#     creating yolox.egg-info
#     writing yolox.egg-info/PKG-INFO
#     writing dependency_links to yolox.egg-info/dependency_links.txt
#     writing requirements to yolox.egg-info/requires.txt
#     writing top-level names to yolox.egg-info/top_level.txt
#     writing manifest file 'yolox.egg-info/SOURCES.txt'
#     reading manifest file 'yolox.egg-info/SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     warning: no files found matching '*.cu' under directory 'yolox'
#     warning: no files found matching '*.cuh' under directory 'yolox'
#     warning: no files found matching '*.cc' under directory 'yolox'
#     adding license file 'LICENSE'
#     writing manifest file 'yolox.egg-info/SOURCES.txt'
#     running build_ext
#     building 'yolox.layers.fast_cocoeval' extension
#     creating /content/YOLOX-fork/build/temp.linux-x86_64-cpython-312/yolox/layers/cocoeval
#     [1/1] c++ -MMD -MF /content/YOLOX-fork/build/temp.linux-x86_64-cpython-312/yolox/layers/cocoeval/cocoeval.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -Iyolox/layers/cocoeval -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/include/python3.12 -c -c /content/YOLOX-fork/yolox/layers/cocoeval/cocoeval.cpp -o /content/YOLOX-fork/build/temp.linux-x86_64-cpython-312/yolox/layers/cocoeval/cocoeval.o -O3 -std=c++14 -g -Wno-reorder -DTORCH_API_INCLUDE_EXTENSION_H -DTORCH_EXTENSION_NAME=fast_cocoeval
#     creating build/lib.linux-x86_64-cpython-312/yolox/layers
#     x86_64-linux-gnu-g++ -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /content/YOLOX-fork/build/temp.linux-x86_64-cpython-312/yolox/layers/cocoeval/cocoeval.o -L/usr/local/lib/python3.12/dist-packages/torch/lib -L/usr/lib/x86_64-linux-gnu -lc10 -ltorch -ltorch_cpu -ltorch_python -o build/lib.linux-x86_64-cpython-312/yolox/layers/fast_cocoeval.cpython-312-x86_64-linux-gnu.so
#     copying build/lib.linux-x86_64-cpython-312/yolox/layers/fast_cocoeval.cpython-312-x86_64-linux-gnu.so -> yolox/layers
#     Creating /usr/local/lib/python3.12/dist-packages/yolox.egg-link (link to .)
#     Adding yolox 0.3.0 to easy-install.pth file
#
#     Installed /content/YOLOX-fork
# Successfully installed yolox-0.3.0

# %%
# verify yolox version
import yolox
print("YOLOX version:", yolox.__version__)
# Out:
# YOLOX version: 0.3.0

# %%
# get YOLO pretrained weights
# !wget -P ./YOLOX_outputs https://github.com/Megvii-BaseDetection/YOLOX/releases/download/0.1.1rc0/yolox_s.pth
# Out:
# --2026-03-05 04:09:55--  https://github.com/Megvii-BaseDetection/YOLOX/releases/download/0.1.1rc0/yolox_s.pth
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/386811486/42c4cb47-f94e-475b-a3a2-57f31f26fa5d?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-03-05T04%3A57%3A55Z&rscd=attachment%3B+filename%3Dyolox_s.pth&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-03-05T03%3A57%3A38Z&ske=2026-03-05T04%3A57%3A55Z&sks=b&skv=2018-11-09&sig=Ha0oSPv11Jg7s6Ps7K4IUldhrF8nwFUXviQDt6hTphk%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3MjY4NTU5NSwibmJmIjoxNzcyNjgzNzk1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.nI3-TZ6Kaa0-jXESPAIIo0VXxWlGPT_x5LpuHakzx7I&response-content-disposition=attachment%3B%20filename%3Dyolox_s.pth&response-content-type=application%2Foctet-stream [following]
# --2026-03-05 04:09:55--  https://release-assets.githubusercontent.com/github-production-release-asset/386811486/42c4cb47-f94e-475b-a3a2-57f31f26fa5d?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-03-05T04%3A57%3A55Z&rscd=attachment%3B+filename%3Dyolox_s.pth&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-03-05T03%3A57%3A38Z&ske=2026-03-05T04%3A57%3A55Z&sks=b&skv=2018-11-09&sig=Ha0oSPv11Jg7s6Ps7K4IUldhrF8nwFUXviQDt6hTphk%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3MjY4NTU5NSwibmJmIjoxNzcyNjgzNzk1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.nI3-TZ6Kaa0-jXESPAIIo0VXxWlGPT_x5LpuHakzx7I&response-content-disposition=attachment%3B%20filename%3Dyolox_s.pth&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72089125 (69M) [application/octet-stream]
# Saving to: ‘./YOLOX_outputs/yolox_s.pth’
#
# yolox_s.pth         100%[===================>]  68.75M  54.3MB/s    in 1.3s
#
# 2026-03-05 04:09:57 (54.3 MB/s) - ‘./YOLOX_outputs/yolox_s.pth’ saved [72089125/72089125]

# %%
# verify the GPU is still there
# !nvidia-smi
# Out:
# Thu Mar  5 04:10:54 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# train
# %cd /content/YOLOX-fork
# !python tools/train.py -f exps/example/custom/yolox_s_3classes.py -d 1 -b 8 --fp16 -o -c ./YOLOX_outputs/yolox_s.pth
# Out:
# /content/YOLOX-fork
# 2026-03-05 04:25:10.336591: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772684710.358092    5195 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772684710.365113    5195 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772684710.383433    5195 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772684710.383473    5195 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772684710.383477    5195 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772684710.383480    5195 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-05 04:25:10.388047: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /content/YOLOX-fork/yolox/core/trainer.py:47: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(enabled=args.fp16)
# 2026-03-05 04:25:15 | INFO     | yolox.core.trainer:132 - args: Namespace(experiment_name='yolox_s_3classes', name=None, dist_backend='nccl', dist_url=None, batch_size=8, devices=1, exp_file='exps/example/custom/yolox_s_3classes.py', resume=False, ckpt='./YOLOX_outputs/yolox_s.pth', start_epoch=None, num_machines=1, machine_rank=0, fp16=True, cache=None, occupy=True, logger='tensorboard', opts=[])
# 2026-03-05 04:25:15 | INFO     | yolox.core.trainer:133 - exp value:
# ╒═══════════════════╤═══════════════════════════════════╕
# │ keys              │ values                            │
# ╞═══════════════════╪═══════════════════════════════════╡
# │ seed              │ None                              │
# ├───────────────────┼───────────────────────────────────┤
# │ output_dir        │ './YOLOX_outputs'                 │
# ├───────────────────┼───────────────────────────────────┤
# │ print_interval    │ 10                                │
# ├───────────────────┼───────────────────────────────────┤
# │ eval_interval     │ 1                                 │
# ├───────────────────┼───────────────────────────────────┤
# │ dataset           │ None                              │
# ├───────────────────┼───────────────────────────────────┤
# │ num_classes       │ 3                                 │
# ├───────────────────┼───────────────────────────────────┤
# │ depth             │ 0.33                              │
# ├───────────────────┼───────────────────────────────────┤
# │ width             │ 0.5                               │
# ├───────────────────┼───────────────────────────────────┤
# │ act               │ 'silu'                            │
# ├───────────────────┼───────────────────────────────────┤
# │ data_num_workers  │ 4                                 │
# ├───────────────────┼───────────────────────────────────┤
# │ input_size        │ (640, 640)                        │
# ├───────────────────┼───────────────────────────────────┤
# │ multiscale_range  │ 5                                 │
# ├───────────────────┼───────────────────────────────────┤
# │ data_dir          │ '../YOLOX-OneShot/datasets/COCO3' │
# ├───────────────────┼───────────────────────────────────┤
# │ train_ann         │ 'instances_train2017.json'        │
# ├───────────────────┼───────────────────────────────────┤
# │ val_ann           │ 'instances_val2017.json'          │
# ├───────────────────┼───────────────────────────────────┤
# │ test_ann          │ 'instances_test2017.json'         │
# ├───────────────────┼───────────────────────────────────┤
# │ mosaic_prob       │ 0.7                               │
# ├───────────────────┼───────────────────────────────────┤
# │ mixup_prob        │ 0.5                               │
# ├───────────────────┼───────────────────────────────────┤
# │ hsv_prob          │ 1.0                               │
# ├───────────────────┼───────────────────────────────────┤
# │ flip_prob         │ 0.0                               │
# ├───────────────────┼───────────────────────────────────┤
# │ degrees           │ 180.0                             │
# ├───────────────────┼───────────────────────────────────┤
# │ translate         │ 0.1                               │
# ├───────────────────┼───────────────────────────────────┤
# │ mosaic_scale      │ (0.1, 2)                          │
# ├───────────────────┼───────────────────────────────────┤
# │ enable_mixup      │ True                              │
# ├───────────────────┼───────────────────────────────────┤
# │ mixup_scale       │ (0.5, 1.5)                        │
# ├───────────────────┼───────────────────────────────────┤
# │ shear             │ 2.0                               │
# ├───────────────────┼───────────────────────────────────┤
# │ warmup_epochs     │ 3                                 │
# ├───────────────────┼───────────────────────────────────┤
# │ max_epoch         │ 100                               │
# ├───────────────────┼───────────────────────────────────┤
# │ warmup_lr         │ 0                                 │
# ├───────────────────┼───────────────────────────────────┤
# │ min_lr_ratio      │ 0.05                              │
# ├───────────────────┼───────────────────────────────────┤
# │ basic_lr_per_img  │ 0.00015625                        │
# ├───────────────────┼───────────────────────────────────┤
# │ scheduler         │ 'yoloxwarmcos'                    │
# ├───────────────────┼───────────────────────────────────┤
# │ no_aug_epochs     │ 5                                 │
# ├───────────────────┼───────────────────────────────────┤
# │ ema               │ True                              │
# ├───────────────────┼───────────────────────────────────┤
# │ weight_decay      │ 0.0005                            │
# ├───────────────────┼───────────────────────────────────┤
# │ momentum          │ 0.9                               │
# ├───────────────────┼───────────────────────────────────┤
# │ save_history_ckpt │ True                              │
# ├───────────────────┼───────────────────────────────────┤
# │ exp_name          │ 'yolox_s_3classes'                │
# ├───────────────────┼───────────────────────────────────┤
# │ test_size         │ (640, 640)                        │
# ├───────────────────┼───────────────────────────────────┤
# │ test_conf         │ 0.01                              │
# ├───────────────────┼───────────────────────────────────┤
# │ nmsthre           │ 0.65                              │
# ├───────────────────┼───────────────────────────────────┤
# │ random_size       │ (18, 22)                          │
# ├───────────────────┼───────────────────────────────────┤
# │ scale             │ (0.5, 1.5)                        │
# ├───────────────────┼───────────────────────────────────┤
# │ perspective       │ 0.0                               │
# ╘═══════════════════╧═══════════════════════════════════╛
# 2026-03-05 04:25:16 | INFO     | yolox.core.trainer:138 - Model Summary: Params: 8.94M, Gflops: 26.76
# 2026-03-05 04:25:16 | INFO     | yolox.core.trainer:338 - loading checkpoint for fine tuning
# 2026-03-05 04:25:16 | WARNING  | yolox.utils.checkpoint:24 - Shape of head.cls_preds.0.weight in checkpoint is torch.Size([80, 128, 1, 1]), while shape of head.cls_preds.0.weight in model is torch.Size([3, 128, 1, 1]).
# 2026-03-05 04:25:16 | WARNING  | yolox.utils.checkpoint:24 - Shape of head.cls_preds.0.bias in checkpoint is torch.Size([80]), while shape of head.cls_preds.0.bias in model is torch.Size([3]).
# 2026-03-05 04:25:16 | WARNING  | yolox.utils.checkpoint:24 - Shape of head.cls_preds.1.weight in checkpoint is torch.Size([80, 128, 1, 1]), while shape of head.cls_preds.1.weight in model is torch.Size([3, 128, 1, 1]).
# 2026-03-05 04:25:16 | WARNING  | yolox.utils.checkpoint:24 - Shape of head.cls_preds.1.bias in checkpoint is torch.Size([80]), while shape of head.cls_preds.1.bias in model is torch.Size([3]).
# 2026-03-05 04:25:16 | WARNING  | yolox.utils.checkpoint:24 - Shape of head.cls_preds.2.weight in checkpoint is torch.Size([80, 128, 1, 1]), while shape of head.cls_preds.2.weight in model is torch.Size([3, 128, 1, 1]).
# 2026-03-05 04:25:16 | WARNING  | yolox.utils.checkpoint:24 - Shape of head.cls_preds.2.bias in checkpoint is torch.Size([80]), while shape of head.cls_preds.2.bias in model is torch.Size([3]).
# 2026-03-05 04:25:16 | INFO     | yolox.data.datasets.coco:63 - loading annotations into memory...
# 2026-03-05 04:25:16 | INFO     | yolox.data.datasets.coco:63 - Done (t=0.00s)
# 2026-03-05 04:25:16 | INFO     | pycocotools.coco:86 - creating index...
# 2026-03-05 04:25:16 | INFO     | pycocotools.coco:86 - index created!
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# 2026-03-05 04:25:16 | INFO     | yolox.core.trainer:157 - init prefetcher, this might take one minute or less...
# /content/YOLOX-fork/yolox/utils/metric.py:43: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /pytorch/torch/csrc/tensor/python_tensor.cpp:78.)
#   x = torch.cuda.FloatTensor(256, 1024, block_mem)
# 2026-03-05 04:25:23 | INFO     | yolox.data.datasets.coco:63 - loading annotations into memory...
# 2026-03-05 04:25:23 | INFO     | yolox.data.datasets.coco:63 - Done (t=0.00s)
# 2026-03-05 04:25:23 | INFO     | pycocotools.coco:86 - creating index...
# 2026-03-05 04:25:23 | INFO     | pycocotools.coco:86 - index created!
# 2026-03-05 04:25:23 | INFO     | yolox.core.trainer:196 - Training start...
# 2026-03-05 04:25:23 | INFO     | yolox.core.trainer:197 -
# YOLOX(
#   (backbone): YOLOPAFPN(
#     (backbone): CSPDarknet(
#       (stem): Focus(
#         (conv): BaseConv(
#           (conv): Conv2d(12, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (dark2): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark3): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark4): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark5): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): SPPBottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): ModuleList(
#             (0): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#             (1): MaxPool2d(kernel_size=9, stride=1, padding=4, dilation=1, ceil_mode=False)
#             (2): MaxPool2d(kernel_size=13, stride=1, padding=6, dilation=1, ceil_mode=False)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#         (2): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#     )
#     (upsample): Upsample(scale_factor=2.0, mode='nearest')
#     (lateral_conv0): BaseConv(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_p4): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (reduce_conv1): BaseConv(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_p3): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (bu_conv2): BaseConv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_n3): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (bu_conv1): BaseConv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_n4): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#   )
#   (head): YOLOXHead(
#     (cls_convs): ModuleList(
#       (0-2): 3 x Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#     )
#     (reg_convs): ModuleList(
#       (0-2): 3 x Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#     )
#     (cls_preds): ModuleList(
#       (0-2): 3 x Conv2d(128, 3, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (reg_preds): ModuleList(
#       (0-2): 3 x Conv2d(128, 4, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (obj_preds): ModuleList(
#       (0-2): 3 x Conv2d(128, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (stems): ModuleList(
#       (0): BaseConv(
#         (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): BaseConv(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): BaseConv(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (l1_loss): L1Loss()
#     (bcewithlog_loss): BCEWithLogitsLoss()
#     (iou_loss): IOUloss()
#   )
# )
# 2026-03-05 04:25:23 | INFO     | yolox.core.trainer:218 - ---> start train epoch1
# /content/YOLOX-fork/yolox/core/trainer.py:106: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=self.amp_training):
# /content/YOLOX-fork/yolox/models/yolo_head.py:474: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# 2026-03-05 04:26:09 | INFO     | yolox.core.trainer:270 - epoch: 1/100, iter: 10/15, gpu mem: 13610Mb, mem: 2.8Gb, iter_time: 4.615s, data_time: 0.007s, total_loss: 7.0, iou_loss: 1.6, l1_loss: 0.0, conf_loss: 3.4, cls_loss: 2.0, lr: 6.173e-05, size: 640, ETA: 1:54:36
# 2026-03-05 04:26:11 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 100% 4/4 [00:02<00:00,  1.83it/s]
# 2026-03-05 04:26:14 | INFO     | yolox.evaluators.coco_evaluator:259 - Evaluate in main process...
# 2026-03-05 04:26:14 | INFO     | yolox.evaluators.coco_evaluator:292 - Loading and preparing results...
# 2026-03-05 04:26:14 | INFO     | yolox.evaluators.coco_evaluator:292 - DONE (t=0.00s)
# 2026-03-05 04:26:14 | INFO     | pycocotools.coco:367 - creating index...
# 2026-03-05 04:26:14 | INFO     | pycocotools.coco:367 - index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.01 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
# 2026-03-05 04:26:14 | INFO     | yolox.core.trainer:381 -
# Average forward time: 39.39 ms, Average NMS time: 1.24 ms, Average inference time: 40.64 ms
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.788
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.958
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.958
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.814
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.784
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.820
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.847
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.847
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.871
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.840
# per class AP:
# | class   | AP     | class   | AP     | class   | AP     |
# |:--------|:-------|:--------|:-------|:--------|:-------|
# | candy   | 71.033 | cards   | 83.228 | cheeto  | 82.038 |
# per class AR:
# | class   | AR     | class   | AR     | class   | AR     |
# |:--------|:-------|:--------|:-------|:--------|:-------|
# | candy   | 83.000 | cards   | 86.429 | cheeto  | 84.545 |
#
# 2026-03-05 04:26:14 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 2026-03-05 04:26:14 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 2026-03-05 04:26:16 | INFO     | yolox.core.trainer:218 - ---> start train epoch2
# 2026-03-05 04:27:01 | INFO     | yolox.core.trainer:270 - epoch: 2/100, iter: 10/15, gpu mem: 13610Mb, mem: 2.9Gb, iter_time: 4.514s, data_time: 0.004s, total_loss: 6.2, iou_loss: 1.3, l1_loss: 0.0, conf_loss: 2.6, cls_loss: 2.3, lr: 3.858e-04, size: 608, ETA: 1:31:48
# 2026-03-05 04:27:03 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 100% 4/4 [00:00<00:00,  4.87it/s]
# 2026-03-05 04:27:04 | INFO     | yolox.evaluators.coco_evaluator:259 - Evaluate in main process...
# 2026-03-05 04:27:04 | INFO     | yolox.evaluators.coco_evaluator:292 - Loading and preparing results...
# 2026-03-05 04:27:04 | INFO     | yolox.evaluators.coco_evaluator:292 - DONE (t=0.00s)
# 2026-03-05 04:27:04 | INFO     | pycocotools.coco:367 - creating index...
# 2026-03-05 04:27:04 | INFO     | pycocotools.coco:367 - index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.01 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
# 2026-03-05 04:27:04 | INFO     | yolox.core.trainer:381 -
# Average forward time: 7.75 ms, Average NMS time: 0.81 ms, Average inference time: 8.55 ms
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.093
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.266
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.150
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.090
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.176
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.236
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.236
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.150
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.294
# per class AP:
# | class   | AP    | class   | AP     | class   | AP    |
# |:--------|:------|:--------|:-------|:--------|:------|
# | candy   | 9.866 | cards   | 18.138 | cheeto  | 0.000 |
# per class AR:
# | class   | AR     | class   | AR     | class   | AR    |
# |:--------|:-------|:--------|:-------|:--------|:------|
# | candy   | 40.000 | cards   | 30.714 | cheeto  | 0.000 |
#
# 2026-03-05 04:27:04 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 2026-03-05 04:27:04 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 2026-03-05 04:27:04 | INFO     | yolox.core.trainer:218 - ---> start train epoch3
# 2026-03-05 04:27:08 | INFO     | yolox.core.trainer:270 - epoch: 3/100, iter: 10/15, gpu mem: 13610Mb, mem: 2.9Gb, iter_time: 0.327s, data_time: 0.003s, total_loss: 7.6, iou_loss: 3.2, l1_loss: 0.0, conf_loss: 3.3, cls_loss: 1.1, lr: 9.877e-04, size: 640, ETA: 0:59:55
# 2026-03-05 04:27:50 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 100% 4/4 [00:01<00:00,  3.82it/s]
# 2026-03-05 04:27:51 | INFO     | yolox.evaluators.coco_evaluator:259 - Evaluate in main process...
# 2026-03-05 04:27:51 | INFO     | yolox.evaluators.coco_evaluator:292 - Loading and preparing results...
# 2026-03-05 04:27:51 | INFO     | yolox.evaluators.coco_evaluator:292 - DONE (t=0.00s)
# Running per image evaluation...
# Evaluate annotation type *bbox*
# 2026-03-05 04:27:51 | INFO     | pycocotools.coco:367 - creating index...
# 2026-03-05 04:27:51 | INFO     | pycocotools.coco:367 - index created!
# COCOeval_opt.evaluate() finished in 0.01 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
# 2026-03-05 04:27:51 | INFO     | yolox.core.trainer:381 -
# Average forward time: 10.05 ms, Average NMS time: 1.67 ms, Average inference time: 11.72 ms
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.014
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.014
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.035
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.047
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.037
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.055
# per class AP:
# | class   | AP    | class   | AP    | class   | AP    |
# |:--------|:------|:--------|:------|:--------|:------|
# | candy   | 0.166 | cards   | 0.303 | cheeto  | 0.198 |
# per class AR:
# | class   | AR    | class   | AR    | class   | AR    |
# |:--------|:------|:--------|:------|:--------|:------|
# | candy   | 6.000 | cards   | 7.143 | cheeto  | 0.909 |
#
# 2026-03-05 04:27:51 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 2026-03-05 04:27:51 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 2026-03-05 04:27:51 | INFO     | yolox.core.trainer:218 - ---> start train epoch4
# 2026-03-05 04:27:55 | INFO     | yolox.core.trainer:270 - epoch: 4/100, iter: 10/15, gpu mem: 13610Mb, mem: 2.9Gb, iter_time: 0.323s, data_time: 0.004s, total_loss: 5.9, iou_loss: 2.2, l1_loss: 0.0, conf_loss: 2.5, cls_loss: 1.1, lr: 1.250e-03, size: 640, ETA: 1:02:55
# 2026-03-05 04:27:56 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 100% 4/4 [00:01<00:00,  3.87it/s]
# 2026-03-05 04:27:58 | INFO     | yolox.evaluators.coco_evaluator:259 - Evaluate in main process...
# 2026-03-05 04:27:58 | INFO     | yolox.evaluators.coco_evaluator:292 - Loading and preparing results...
# 2026-03-05 04:27:58 | INFO     | yolox.evaluators.coco_evaluator:292 - DONE (t=0.00s)
# 2026-03-05 04:27:58 | INFO     | pycocotools.coco:367 - creating index...
# 2026-03-05 04:27:58 | INFO     | pycocotools.coco:367 - index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.01 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
# 2026-03-05 04:27:58 | INFO     | yolox.core.trainer:381 -
# Average forward time: 9.34 ms, Average NMS time: 0.77 ms, Average inference time: 10.11 ms
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.014
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.053
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.065
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.011
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.047
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.100
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.103
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.087
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.111
# per class AP:
# | class   | AP    | class   | AP    | class   | AP    |
# |:--------|:------|:--------|:------|:--------|:------|
# | candy   | 0.000 | cards   | 3.909 | cheeto  | 0.169 |
# per class AR:
# | class   | AR    | class   | AR     | class   | AR    |
# |:--------|:------|:--------|:-------|:--------|:------|
# | candy   | 0.000 | cards   | 23.571 | cheeto  | 7.273 |
#
# 2026-03-05 04:27:58 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 2026-03-05 04:27:58 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 2026-03-05 04:27:58 | INFO     | yolox.core.trainer:218 - ---> start train epoch5
# 2026-03-05 04:28:03 | INFO     | yolox.core.trainer:270 - epoch: 5/100, iter: 10/15, gpu mem: 13610Mb, mem: 2.9Gb, iter_time: 0.446s, data_time: 0.003s, total_loss: 6.8, iou_loss: 2.4, l1_loss: 0.0, conf_loss: 3.0, cls_loss: 1.4, lr: 1.249e-03, size: 640, ETA: 0:51:02
# 2026-03-05 04:28:05 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 100% 4/4 [00:01<00:00,  3.28it/s]
# 2026-03-05 04:28:06 | INFO     | yolox.evaluators.coco_evaluator:259 - Evaluate in main process...
# 2026-03-05 04:28:06 | INFO     | yolox.evaluators.coco_evaluator:292 - Loading and preparing results...
# 2026-03-05 04:28:06 | INFO     | yolox.evaluators.coco_evaluator:292 - DONE (t=0.01s)
# 2026-03-05 04:28:06 | INFO     | pycocotools.coco:367 - creating index...
# Running per image evaluation...
# Evaluate annotation type *bbox*
# 2026-03-05 04:28:06 | INFO     | pycocotools.coco:367 - index created!
# COCOeval_opt.evaluate() finished in 0.01 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
# 2026-03-05 04:28:06 | INFO     | yolox.core.trainer:381 -
# Average forward time: 7.79 ms, Average NMS time: 1.14 ms, Average inference time: 8.93 ms
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.009
# per class AP:
# | class   | AP    | class   | AP    | class   | AP    |
# |:--------|:------|:--------|:------|:--------|:------|
# | candy   | 0.000 | cards   | 0.000 | cheeto  | 0.016 |
# per class AR:
# | class   | AR    | class   | AR    | class   | AR    |
# |:--------|:------|:--------|:------|:--------|:------|
# | candy   | 0.000 | cards   | 0.000 | cheeto  | 2.727 |
#
# 2026-03-05 04:28:06 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 2026-03-05 04:28:07 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 2026-03-05 04:28:07 | INFO     | yolox.core.trainer:218 - ---> start train epoch6
# 2026-03-05 04:28:53 | INFO     | yolox.core.trainer:270 - epoch: 6/100, iter: 10/15, gpu mem: 13610Mb, mem: 3.1Gb, iter_time: 4.669s, data_time: 0.004s, total_loss: 4.7, iou_loss: 2.0, l1_loss: 0.0, conf_loss: 1.7, cls_loss: 1.0, lr: 1.248e-03, size: 576, ETA: 0:55:05
# 2026-03-05 04:28:55 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 100% 4/4 [00:00<00:00,  4.15it/s]
# 2026-03-05 04:28:57 | INFO     | yolox.evaluators.coco_evaluator:259 - Evaluate in main process...
# 2026-03-05 04:28:57 | INFO     | yolox.evaluators.coco_evaluator:292 - Loading and preparing results...
# 2026-03-05 04:28:57 | INFO     | yolox.evaluators.coco_evaluator:292 - DONE (t=0.00s)
# Running per image evaluation...
# Evaluate annotation type *bbox*
# 2026-03-05 04:28:57 | INFO     | pycocotools.coco:367 - creating index...
# 2026-03-05 04:28:57 | INFO     | pycocotools.coco:367 - index created!
# COCOeval_opt.evaluate() finished in 0.01 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
# 2026-03-05 04:28:57 | INFO     | yolox.core.trainer:381 -
# Average forward time: 9.87 ms, Average NMS time: 0.83 ms, Average inference time: 10.70 ms
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.047
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.152
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.025
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.139
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.097
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.124
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.175
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.091
# per class AP:
# | class   | AP    | class   | AP    | class   | AP    |
# |:--------|:------|:--------|:------|:--------|:------|
# ...
# Average forward time: 7.69 ms, Average NMS time: 0.76 ms, Average inference time: 8.46 ms
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.908
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.904
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.916
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.926
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.926
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.926
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.904
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.936
# per class AP:
# | class   | AP     | class   | AP     | class   | AP     |
# |:--------|:-------|:--------|:-------|:--------|:-------|
# | candy   | 94.411 | cards   | 91.817 | cheeto  | 86.181 |
# per class AR:
# | class   | AR     | class   | AR     | class   | AR     |
# |:--------|:-------|:--------|:-------|:--------|:-------|
# | candy   | 95.000 | cards   | 93.571 | cheeto  | 89.091 |
#
# 2026-03-05 04:41:07 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 2026-03-05 04:41:07 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 2026-03-05 04:41:07 | INFO     | yolox.core.trainer:218 - ---> start train epoch96
# 2026-03-05 04:41:09 | INFO     | yolox.core.trainer:270 - epoch: 96/100, iter: 10/15, gpu mem: 13610Mb, mem: 3.1Gb, iter_time: 0.215s, data_time: 0.002s, total_loss: 1.0, iou_loss: 0.5, l1_loss: 0.1, conf_loss: 0.1, cls_loss: 0.2, lr: 6.250e-05, size: 576, ETA: 0:00:33
# 2026-03-05 04:41:11 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 100% 4/4 [00:01<00:00,  3.25it/s]
# 2026-03-05 04:41:13 | INFO     | yolox.evaluators.coco_evaluator:259 - Evaluate in main process...
# 2026-03-05 04:41:13 | INFO     | yolox.evaluators.coco_evaluator:292 - Loading and preparing results...
# 2026-03-05 04:41:13 | INFO     | yolox.evaluators.coco_evaluator:292 - DONE (t=0.00s)
# 2026-03-05 04:41:13 | INFO     | pycocotools.coco:367 - creating index...
# Running per image evaluation...
# Evaluate annotation type *bbox*
# 2026-03-05 04:41:13 | INFO     | pycocotools.coco:367 - index created!
# COCOeval_opt.evaluate() finished in 0.01 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
# 2026-03-05 04:41:13 | INFO     | yolox.core.trainer:381 -
# Average forward time: 8.13 ms, Average NMS time: 1.21 ms, Average inference time: 9.35 ms
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.923
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.884
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.940
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.935
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.935
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.935
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.883
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.952
# per class AP:
# | class   | AP     | class   | AP     | class   | AP     |
# |:--------|:-------|:--------|:-------|:--------|:-------|
# | candy   | 91.683 | cards   | 95.188 | cheeto  | 90.020 |
# per class AR:
# | class   | AR     | class   | AR     | class   | AR     |
# |:--------|:-------|:--------|:-------|:--------|:-------|
# | candy   | 93.000 | cards   | 95.714 | cheeto  | 91.818 |
#
# 2026-03-05 04:41:13 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 2026-03-05 04:41:13 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 2026-03-05 04:41:13 | INFO     | yolox.core.trainer:218 - ---> start train epoch97
# 2026-03-05 04:41:15 | INFO     | yolox.core.trainer:270 - epoch: 97/100, iter: 10/15, gpu mem: 13610Mb, mem: 3.1Gb, iter_time: 0.219s, data_time: 0.002s, total_loss: 1.1, iou_loss: 0.5, l1_loss: 0.1, conf_loss: 0.3, cls_loss: 0.2, lr: 6.250e-05, size: 640, ETA: 0:00:25
# 2026-03-05 04:41:16 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 100% 4/4 [00:00<00:00,  4.28it/s]
# 2026-03-05 04:41:17 | INFO     | yolox.evaluators.coco_evaluator:259 - Evaluate in main process...
# 2026-03-05 04:41:17 | INFO     | yolox.evaluators.coco_evaluator:292 - Loading and preparing results...
# 2026-03-05 04:41:17 | INFO     | yolox.evaluators.coco_evaluator:292 - DONE (t=0.00s)
# 2026-03-05 04:41:17 | INFO     | pycocotools.coco:367 - creating index...
# Running per image evaluation...
# Evaluate annotation type *bbox*
# 2026-03-05 04:41:17 | INFO     | pycocotools.coco:367 - index created!
# COCOeval_opt.evaluate() finished in 0.00 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
# 2026-03-05 04:41:17 | INFO     | yolox.core.trainer:381 -
# Average forward time: 7.90 ms, Average NMS time: 0.76 ms, Average inference time: 8.66 ms
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.924
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.884
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.943
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.936
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.936
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.936
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.883
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.953
# per class AP:
# | class   | AP     | class   | AP     | class   | AP     |
# |:--------|:-------|:--------|:-------|:--------|:-------|
# | candy   | 93.193 | cards   | 93.784 | cheeto  | 90.342 |
# per class AR:
# | class   | AR     | class   | AR     | class   | AR     |
# |:--------|:-------|:--------|:-------|:--------|:-------|
# | candy   | 94.000 | cards   | 95.000 | cheeto  | 91.818 |
#
# 2026-03-05 04:41:17 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 2026-03-05 04:41:18 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 2026-03-05 04:41:18 | INFO     | yolox.core.trainer:218 - ---> start train epoch98
# 2026-03-05 04:41:20 | INFO     | yolox.core.trainer:270 - epoch: 98/100, iter: 10/15, gpu mem: 13610Mb, mem: 3.1Gb, iter_time: 0.210s, data_time: 0.003s, total_loss: 0.8, iou_loss: 0.4, l1_loss: 0.1, conf_loss: 0.1, cls_loss: 0.2, lr: 6.250e-05, size: 576, ETA: 0:00:17
# 2026-03-05 04:41:21 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 100% 4/4 [00:00<00:00,  4.58it/s]
# 2026-03-05 04:41:22 | INFO     | yolox.evaluators.coco_evaluator:259 - Evaluate in main process...
# 2026-03-05 04:41:22 | INFO     | yolox.evaluators.coco_evaluator:292 - Loading and preparing results...
# 2026-03-05 04:41:22 | INFO     | yolox.evaluators.coco_evaluator:292 - DONE (t=0.00s)
# 2026-03-05 04:41:22 | INFO     | pycocotools.coco:367 - creating index...
# 2026-03-05 04:41:22 | INFO     | pycocotools.coco:367 - index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.00 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
# 2026-03-05 04:41:22 | INFO     | yolox.core.trainer:381 -
# Average forward time: 7.91 ms, Average NMS time: 0.81 ms, Average inference time: 8.72 ms
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.920
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.888
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.932
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.930
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.930
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.930
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.887
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.944
# per class AP:
# | class   | AP     | class   | AP     | class   | AP     |
# |:--------|:-------|:--------|:-------|:--------|:-------|
# | candy   | 91.980 | cards   | 93.545 | cheeto  | 90.342 |
# per class AR:
# | class   | AR     | class   | AR     | class   | AR     |
# |:--------|:-------|:--------|:-------|:--------|:-------|
# | candy   | 93.000 | cards   | 94.286 | cheeto  | 91.818 |
#
# 2026-03-05 04:41:22 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 2026-03-05 04:41:22 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 2026-03-05 04:41:23 | INFO     | yolox.core.trainer:218 - ---> start train epoch99
# 2026-03-05 04:41:26 | INFO     | yolox.core.trainer:270 - epoch: 99/100, iter: 10/15, gpu mem: 13610Mb, mem: 3.1Gb, iter_time: 0.323s, data_time: 0.003s, total_loss: 0.7, iou_loss: 0.3, l1_loss: 0.1, conf_loss: 0.1, cls_loss: 0.2, lr: 6.250e-05, size: 576, ETA: 0:00:10
# 2026-03-05 04:41:27 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 100% 4/4 [00:00<00:00,  4.36it/s]
# 2026-03-05 04:41:28 | INFO     | yolox.evaluators.coco_evaluator:259 - Evaluate in main process...
# 2026-03-05 04:41:28 | INFO     | yolox.evaluators.coco_evaluator:292 - Loading and preparing results...
# 2026-03-05 04:41:28 | INFO     | yolox.evaluators.coco_evaluator:292 - DONE (t=0.00s)
# 2026-03-05 04:41:28 | INFO     | pycocotools.coco:367 - creating index...
# Running per image evaluation...
# Evaluate annotation type *bbox*
# 2026-03-05 04:41:28 | INFO     | pycocotools.coco:367 - index created!
# COCOeval_opt.evaluate() finished in 0.00 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
# 2026-03-05 04:41:28 | INFO     | yolox.core.trainer:381 -
# Average forward time: 8.45 ms, Average NMS time: 0.80 ms, Average inference time: 9.25 ms
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.930
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.884
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.949
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.939
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.939
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.939
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.883
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.956
# per class AP:
# | class   | AP     | class   | AP     | class   | AP     |
# |:--------|:-------|:--------|:-------|:--------|:-------|
# | candy   | 93.391 | cards   | 94.409 | cheeto  | 91.154 |
# per class AR:
# | class   | AR     | class   | AR     | class   | AR     |
# |:--------|:-------|:--------|:-------|:--------|:-------|
# | candy   | 94.000 | cards   | 95.000 | cheeto  | 92.727 |
#
# 2026-03-05 04:41:28 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 2026-03-05 04:41:28 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 2026-03-05 04:41:29 | INFO     | yolox.core.trainer:218 - ---> start train epoch100
# 2026-03-05 04:41:31 | INFO     | yolox.core.trainer:270 - epoch: 100/100, iter: 10/15, gpu mem: 13610Mb, mem: 3.1Gb, iter_time: 0.224s, data_time: 0.003s, total_loss: 0.8, iou_loss: 0.4, l1_loss: 0.1, conf_loss: 0.2, cls_loss: 0.2, lr: 6.250e-05, size: 640, ETA: 0:00:02
# 2026-03-05 04:41:32 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 100% 4/4 [00:00<00:00,  4.49it/s]
# 2026-03-05 04:41:33 | INFO     | yolox.evaluators.coco_evaluator:259 - Evaluate in main process...
# 2026-03-05 04:41:33 | INFO     | yolox.evaluators.coco_evaluator:292 - Loading and preparing results...
# 2026-03-05 04:41:33 | INFO     | yolox.evaluators.coco_evaluator:292 - DONE (t=0.00s)
# 2026-03-05 04:41:33 | INFO     | pycocotools.coco:367 - creating index...
# Running per image evaluation...
# Evaluate annotation type *bbox*
# 2026-03-05 04:41:33 | INFO     | pycocotools.coco:367 - index created!
# COCOeval_opt.evaluate() finished in 0.00 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
# 2026-03-05 04:41:33 | INFO     | yolox.core.trainer:381 -
# Average forward time: 8.95 ms, Average NMS time: 0.83 ms, Average inference time: 9.77 ms
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.933
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.900
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.947
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.945
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.945
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.945
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.958
# per class AP:
# | class   | AP     | class   | AP     | class   | AP     |
# |:--------|:-------|:--------|:-------|:--------|:-------|
# | candy   | 92.995 | cards   | 95.265 | cheeto  | 91.728 |
# per class AR:
# | class   | AR     | class   | AR     | class   | AR     |
# |:--------|:-------|:--------|:-------|:--------|:-------|
# | candy   | 94.000 | cards   | 95.714 | cheeto  | 93.636 |
#
# 2026-03-05 04:41:33 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 2026-03-05 04:41:33 | INFO     | yolox.core.trainer:402 - Save weights to ./YOLOX_outputs/yolox_s_3classes
# 2026-03-05 04:41:34 | INFO     | yolox.core.trainer:200 - Training of experiment is done and the best AP is 93.33

# %%
# save the best model
from google.colab import files
files.download('/content/YOLOX-fork/YOLOX_outputs/yolox_s_3classes/best_ckpt.pth')

# %%
# evaluate with the validation set
# !pwd
# !python -m yolox.tools.eval \
-f exps/example/custom/yolox_s_3classes.py \
-c YOLOX_outputs/yolox_s_3classes/best_ckpt.pth \
-b 8 \
-d 1 \
--conf 0.001
# Out:
# /content/YOLOX-fork
# 2026-03-05 05:14:00.793393: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772687640.814086   19278 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772687640.820934   19278 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772687640.838904   19278 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772687640.838929   19278 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772687640.838933   19278 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772687640.838936   19278 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-05 05:14:00.843508: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-03-05 05:14:06 | INFO     | __main__:139 - Args: Namespace(experiment_name='yolox_s_3classes', name=None, dist_backend='nccl', dist_url=None, batch_size=8, devices=1, num_machines=1, machine_rank=0, exp_file='exps/example/custom/yolox_s_3classes.py', ckpt='YOLOX_outputs/yolox_s_3classes/best_ckpt.pth', conf=0.001, nms=None, tsize=None, seed=None, fp16=False, fuse=False, trt=False, legacy=False, test=False, speed=False, opts=[])
# 2026-03-05 05:14:07 | INFO     | __main__:149 - Model Summary: Params: 8.94M, Gflops: 26.76
# 2026-03-05 05:14:07 | INFO     | __main__:150 - Model Structure:
# YOLOX(
#   (backbone): YOLOPAFPN(
#     (backbone): CSPDarknet(
#       (stem): Focus(
#         (conv): BaseConv(
#           (conv): Conv2d(12, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#       (dark2): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark3): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark4): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (dark5): Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): SPPBottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): ModuleList(
#             (0): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#             (1): MaxPool2d(kernel_size=9, stride=1, padding=4, dilation=1, ceil_mode=False)
#             (2): MaxPool2d(kernel_size=13, stride=1, padding=6, dilation=1, ceil_mode=False)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#         (2): CSPLayer(
#           (conv1): BaseConv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv3): BaseConv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (conv1): BaseConv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (conv2): BaseConv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#     )
#     (upsample): Upsample(scale_factor=2.0, mode='nearest')
#     (lateral_conv0): BaseConv(
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_p4): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (reduce_conv1): BaseConv(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_p3): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (bu_conv2): BaseConv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_n3): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (bu_conv1): BaseConv(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (C3_n4): CSPLayer(
#       (conv1): BaseConv(
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv2): BaseConv(
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (conv3): BaseConv(
#         (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (conv1): BaseConv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (conv2): BaseConv(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#   )
#   (head): YOLOXHead(
#     (cls_convs): ModuleList(
#       (0-2): 3 x Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#     )
#     (reg_convs): ModuleList(
#       (0-2): 3 x Sequential(
#         (0): BaseConv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (1): BaseConv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#       )
#     )
#     (cls_preds): ModuleList(
#       (0-2): 3 x Conv2d(128, 3, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (reg_preds): ModuleList(
#       (0-2): 3 x Conv2d(128, 4, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (obj_preds): ModuleList(
#       (0-2): 3 x Conv2d(128, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (stems): ModuleList(
#       (0): BaseConv(
#         (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): BaseConv(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): BaseConv(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#     )
#     (l1_loss): L1Loss()
#     (bcewithlog_loss): BCEWithLogitsLoss()
#     (iou_loss): IOUloss()
#   )
# )
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# 2026-03-05 05:14:07 | INFO     | yolox.data.datasets.coco:63 - loading annotations into memory...
# 2026-03-05 05:14:07 | INFO     | yolox.data.datasets.coco:63 - Done (t=0.00s)
# 2026-03-05 05:14:07 | INFO     | pycocotools.coco:86 - creating index...
# 2026-03-05 05:14:07 | INFO     | pycocotools.coco:86 - index created!
# 2026-03-05 05:14:07 | INFO     | __main__:165 - loading checkpoint from YOLOX_outputs/yolox_s_3classes/best_ckpt.pth
# 2026-03-05 05:14:07 | INFO     | __main__:169 - loaded checkpoint done.
#   0% 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# 100% 4/4 [00:03<00:00,  1.29it/s]
# /content/YOLOX-fork/yolox/evaluators/coco_evaluator.py:189: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /pytorch/torch/csrc/tensor/python_tensor.cpp:78.)
#   statistics = torch.cuda.FloatTensor([inference_time, nms_time, n_samples])
# 2026-03-05 05:14:10 | INFO     | yolox.evaluators.coco_evaluator:259 - Evaluate in main process...
# 2026-03-05 05:14:10 | INFO     | yolox.evaluators.coco_evaluator:292 - Loading and preparing results...
# 2026-03-05 05:14:10 | INFO     | yolox.evaluators.coco_evaluator:292 - DONE (t=0.00s)
# 2026-03-05 05:14:10 | INFO     | pycocotools.coco:367 - creating index...
# 2026-03-05 05:14:10 | INFO     | pycocotools.coco:367 - index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.00 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
# 2026-03-05 05:14:10 | INFO     | __main__:196 -
# Average forward time: 61.69 ms, Average NMS time: 11.40 ms, Average inference time: 73.09 ms
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.933
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.900
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.947
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.945
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.945
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.945
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.958
# per class AP:
# | class   | AP     | class   | AP     | class   | AP     |
# |:--------|:-------|:--------|:-------|:--------|:-------|
# | candy   | 92.995 | cards   | 95.265 | cheeto  | 91.728 |
# per class AR:
# | class   | AR     | class   | AR     | class   | AR     |
# |:--------|:-------|:--------|:-------|:--------|:-------|
# | candy   | 94.000 | cards   | 95.714 | cheeto  | 93.636 |

# %%
# show annotated images from validation set
# !python tools/demo.py image \
    -f exps/example/custom/yolox_s_3classes.py \
    -c YOLOX_outputs/yolox_s_3classes/best_ckpt.pth \
    --path ../YOLOX-OneShot/datasets/COCO3/val2017 \
    --conf 0.5 \
    --tsize 640 \
    --save_result \
    --device cuda
# Out:
# 2026-03-05 06:01:12.501 | INFO     | __main__:main:262 - Args: Namespace(demo='image', experiment_name='yolox_s_3classes', name=None, path='../YOLOX-OneShot/datasets/COCO3/val2017', camid=0, save_result=True, exp_file='exps/example/custom/yolox_s_3classes.py', ckpt='YOLOX_outputs/yolox_s_3classes/best_ckpt.pth', device='cuda', conf=0.5, nms=0.3, tsize=640, fp16=False, legacy=False, fuse=False, trt=False)
# 2026-03-05 06:01:12.739 | INFO     | __main__:main:272 - Model Summary: Params: 8.94M, Gflops: 26.76
# 2026-03-05 06:01:12.740 | INFO     | __main__:main:285 - loading checkpoint
# 2026-03-05 06:01:12.927 | INFO     | __main__:main:290 - loaded checkpoint done.
# 2026-03-05 06:01:13.329 | INFO     | __main__:inference:168 - Infer time: 0.3886s
# 2026-03-05 06:01:13.330 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/candy.300.02_640x640.png
# 2026-03-05 06:01:13.717 | INFO     | __main__:inference:168 - Infer time: 0.3617s
# 2026-03-05 06:01:13.718 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/candy.300.05_640x640.png
# 2026-03-05 06:01:14.102 | INFO     | __main__:inference:168 - Infer time: 0.3590s
# 2026-03-05 06:01:14.103 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/candy.300.13_640x640.png
# 2026-03-05 06:01:14.502 | INFO     | __main__:inference:168 - Infer time: 0.3749s
# 2026-03-05 06:01:14.503 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/candy.450.06_640x640.png
# 2026-03-05 06:01:14.886 | INFO     | __main__:inference:168 - Infer time: 0.3591s
# 2026-03-05 06:01:14.887 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/candy.600.05_640x640.png
# 2026-03-05 06:01:15.274 | INFO     | __main__:inference:168 - Infer time: 0.3618s
# 2026-03-05 06:01:15.274 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/candy.600.07_640x640.png
# 2026-03-05 06:01:15.669 | INFO     | __main__:inference:168 - Infer time: 0.3701s
# 2026-03-05 06:01:15.670 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/candy.600.10_640x640.png
# 2026-03-05 06:01:16.035 | INFO     | __main__:inference:168 - Infer time: 0.3406s
# 2026-03-05 06:01:16.036 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cards.200.02_640x640.png
# 2026-03-05 06:01:16.420 | INFO     | __main__:inference:168 - Infer time: 0.3599s
# 2026-03-05 06:01:16.421 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cards.200.06_640x640.png
# 2026-03-05 06:01:16.801 | INFO     | __main__:inference:168 - Infer time: 0.3565s
# 2026-03-05 06:01:16.802 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cards.300.04_640x640.png
# 2026-03-05 06:01:17.183 | INFO     | __main__:inference:168 - Infer time: 0.3560s
# 2026-03-05 06:01:17.183 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cards.300.16_640x640.png
# 2026-03-05 06:01:17.556 | INFO     | __main__:inference:168 - Infer time: 0.3459s
# 2026-03-05 06:01:17.556 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cards.300.18_640x640.png
# 2026-03-05 06:01:17.933 | INFO     | __main__:inference:168 - Infer time: 0.3453s
# 2026-03-05 06:01:17.934 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cards.300.24_640x640.png
# 2026-03-05 06:01:18.304 | INFO     | __main__:inference:168 - Infer time: 0.3456s
# 2026-03-05 06:01:18.304 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cards.300.25_640x640.png
# 2026-03-05 06:01:18.701 | INFO     | __main__:inference:168 - Infer time: 0.3720s
# 2026-03-05 06:01:18.702 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cards.300.29_640x640.png
# 2026-03-05 06:01:19.081 | INFO     | __main__:inference:168 - Infer time: 0.3490s
# 2026-03-05 06:01:19.082 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cards.450.05_640x640.png
# 2026-03-05 06:01:19.510 | INFO     | __main__:inference:168 - Infer time: 0.4036s
# 2026-03-05 06:01:19.510 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cards.450.07_640x640.png
# 2026-03-05 06:01:19.973 | INFO     | __main__:inference:168 - Infer time: 0.4317s
# 2026-03-05 06:01:19.973 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cards.600.01_640x640.png
# 2026-03-05 06:01:20.391 | INFO     | __main__:inference:168 - Infer time: 0.3858s
# 2026-03-05 06:01:20.392 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cheetos.300.01_640x640.png
# 2026-03-05 06:01:20.943 | INFO     | __main__:inference:168 - Infer time: 0.5256s
# 2026-03-05 06:01:20.944 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cheetos.300.03_640x640.png
# 2026-03-05 06:01:21.515 | INFO     | __main__:inference:168 - Infer time: 0.5316s
# 2026-03-05 06:01:21.515 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cheetos.300.08_640x640.png
# 2026-03-05 06:01:22.050 | INFO     | __main__:inference:168 - Infer time: 0.4951s
# 2026-03-05 06:01:22.050 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cheetos.300.55_640x640.png
# 2026-03-05 06:01:22.611 | INFO     | __main__:inference:168 - Infer time: 0.5249s
# 2026-03-05 06:01:22.612 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cheetos.450.51_640x640.png
# 2026-03-05 06:01:23.185 | INFO     | __main__:inference:168 - Infer time: 0.5369s
# 2026-03-05 06:01:23.186 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cheetos.450.56_640x640.png
# 2026-03-05 06:01:23.574 | INFO     | __main__:inference:168 - Infer time: 0.3572s
# 2026-03-05 06:01:23.574 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cheetos.600.54_640x640.png
# 2026-03-05 06:01:23.971 | INFO     | __main__:inference:168 - Infer time: 0.3711s
# 2026-03-05 06:01:23.971 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cheetos.600.57_640x640.png
# 2026-03-05 06:01:24.357 | INFO     | __main__:inference:168 - Infer time: 0.3606s
# 2026-03-05 06:01:24.358 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/three.450.50_640x640.png
# 2026-03-05 06:01:24.748 | INFO     | __main__:inference:168 - Infer time: 0.3642s
# 2026-03-05 06:01:24.749 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/three.450.52_640x640.png
# 2026-03-05 06:01:25.141 | INFO     | __main__:inference:168 - Infer time: 0.3676s
# 2026-03-05 06:01:25.142 | INFO     | __main__:image_demo:205 - Saving detection result in ./YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/three.600.51_640x640.png

# %%
# save the annotated images
# zip the directory
# !zip -r yolox_val_annotated.zip ./YOLOX_outputs/yolox_s_3classes/vis_res/
from google.colab import files
files.download("yolox_val_annotated.zip")
# Out:
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/ (stored 0%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/.ipynb_checkpoints/ (stored 0%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/ (stored 0%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/cheetos.450.51_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/cheetos.300.01_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/cards.450.07_640x640.png (deflated 4%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/cheetos.300.55_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/three.450.52_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/candy.300.05_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/three.600.51_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/cheetos.600.57_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/cheetos.300.08_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/cards.300.24_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/candy.300.13_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/cards.200.06_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/three.450.50_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/candy.450.06_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/candy.300.02_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/cards.300.04_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/cards.600.01_640x640.png (deflated 4%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/cards.450.05_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/candy.600.05_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/cards.300.18_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/cards.300.25_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/candy.600.10_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/cheetos.600.54_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/cards.300.16_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/cheetos.450.56_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/cheetos.300.03_640x640.png (deflated 1%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/cards.300.29_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/cards.200.02_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_48_24/candy.600.07_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/ (stored 0%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/cheetos.450.51_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/cheetos.300.01_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/cards.450.07_640x640.png (deflated 4%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/cheetos.300.55_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/three.450.52_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/candy.300.05_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/three.600.51_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/cheetos.600.57_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/cheetos.300.08_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/cards.300.24_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/candy.300.13_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/cards.200.06_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/three.450.50_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/candy.450.06_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/candy.300.02_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/cards.300.04_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/cards.600.01_640x640.png (deflated 4%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/cards.450.05_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/candy.600.05_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/cards.300.18_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/cards.300.25_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/candy.600.10_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/cheetos.600.54_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/cards.300.16_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/cheetos.450.56_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/cheetos.300.03_640x640.png (deflated 1%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/cards.300.29_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/cards.200.02_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_58_11/candy.600.07_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/ (stored 0%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/cheetos.450.51_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/cheetos.300.01_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/cards.450.07_640x640.png (deflated 4%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/cheetos.300.55_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/three.450.52_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/candy.300.05_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/three.600.51_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/cheetos.600.57_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/cheetos.300.08_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/cards.300.24_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/candy.300.13_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/cards.200.06_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/three.450.50_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/candy.450.06_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/candy.300.02_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/cards.300.04_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/cards.600.01_640x640.png (deflated 4%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/cards.450.05_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/candy.600.05_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/cards.300.18_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/cards.300.25_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/candy.600.10_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/cheetos.600.54_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/cards.300.16_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/cheetos.450.56_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/cheetos.300.03_640x640.png (deflated 1%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/cards.300.29_640x640.png (deflated 3%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/cards.200.02_640x640.png (deflated 2%)
# updating: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_05_52_53/candy.600.07_640x640.png (deflated 3%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/ (stored 0%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cheetos.450.51_640x640.png (deflated 3%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cheetos.300.01_640x640.png (deflated 2%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cards.450.07_640x640.png (deflated 4%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cheetos.300.55_640x640.png (deflated 2%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/three.450.52_640x640.png (deflated 3%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/candy.300.05_640x640.png (deflated 2%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/three.600.51_640x640.png (deflated 3%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cheetos.600.57_640x640.png (deflated 3%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cheetos.300.08_640x640.png (deflated 2%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cards.300.24_640x640.png (deflated 2%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/candy.300.13_640x640.png (deflated 2%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cards.200.06_640x640.png (deflated 2%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/three.450.50_640x640.png (deflated 2%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/candy.450.06_640x640.png (deflated 3%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/candy.300.02_640x640.png (deflated 2%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cards.300.04_640x640.png (deflated 3%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cards.600.01_640x640.png (deflated 4%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cards.450.05_640x640.png (deflated 3%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/candy.600.05_640x640.png (deflated 3%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cards.300.18_640x640.png (deflated 3%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cards.300.25_640x640.png (deflated 3%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/candy.600.10_640x640.png (deflated 3%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cheetos.600.54_640x640.png (deflated 3%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cards.300.16_640x640.png (deflated 2%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cheetos.450.56_640x640.png (deflated 3%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cheetos.300.03_640x640.png (deflated 1%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cards.300.29_640x640.png (deflated 3%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/cards.200.02_640x640.png (deflated 2%)
#   adding: YOLOX_outputs/yolox_s_3classes/vis_res/2026_03_05_06_01_12/candy.600.07_640x640.png (deflated 3%)
